# %%
# !pip install transformers datasets

# %%
import pandas as pd

data_pth = "./data/imdb"
train = pd.read_csv(f"{data_pth}/train_cleaned.csv") # These use same cleaning technique as traditional pipe
val = pd.read_csv(f"{data_pth}/val_cleaned.csv")
test = pd.read_csv(f"{data_pth}/test_cleaned.csv")

train.head(5)
# Out:
#                                                 text  label  \
# 0  Everyone involved (and the audience) should se...      0
# 1  The Williams family live on a ranch located in...      1
# 2  This movie surprised me in a good way. From th...      1
# 3  Forget Neo and Bourne and all those half-baked...      1
# 4  I figured that any horror film with Orson Well...      0
#
#                                         text_cleaned
# 0  everyone involved and the audience should seek...
# 1  the williams family live on a ranch located in...
# 2  this movie surprised me in a good way from the...
# 3  forget neo and bourne and all those halfbaked ...
# 4  i figured that any horror film with orson well...

# %% [markdown]
# ### Data
# Create Vocabulary and Tokenizer; Prepare PyTorch dataloaders

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from datasets import Dataset

vocab_size = 89527

dataset = {"train": Dataset.from_pandas(train),
           "val": Dataset.from_pandas(val),
           "test": Dataset.from_pandas(test) }

tokenizer = Tokenizer(WordLevel(unk_token='<unk>'))
tokenizer.pre_tokenizer = WhitespaceSplit()

trainer = WordLevelTrainer( # should only be 89527 distinct types in IMDB50k
    vocab_size=vocab_size, special_tokens=["<unk>", "<pad>"])
generator_bsz = 512
all_splits_generator = (dataset[split][i:i+generator_bsz]["text_cleaned"]
                        for split in ["train", "val", "test"]
                          for i in range (0, len(dataset[split]), generator_bsz))
tokenizer.train_from_iterator(all_splits_generator, trainer)

orig_vocab = tokenizer.get_vocab()
word_types = sorted(list(orig_vocab.keys()), key=lambda w: orig_vocab[w])
vocab = {w: i for i, w in enumerate(word_types)}
vocab_size = len(vocab)
pad_id = vocab["<pad>"]
print("Vocabulary Size: ", vocab_size)
# Out:
# Vocabulary Size:  89527

# %%
from transformers import BertTokenizer
import torch.utils.data as torch_data
import torch

class IMDB50(torch_data.Dataset):
    def __init__(self,
                 text,
                 labels,
                 tokenizer,):

        self.all_text = text
        self.all_labels = labels
        self.tokenizer = tokenizer

        self.is_bert = isinstance(tokenizer, BertTokenizer)

    def __len__(self):
        return len(self.all_text)

    def __getitem__(self, idx):

        if not self.is_bert:
            input_ids = torch.LongTensor(self.tokenizer.encode(self.all_text[idx]).ids)
        else:
            input_ids = self.tokenizer(self.all_text[idx], return_tensors='pt', max_length=512,
                                       padding="do_not_pad", truncation=True).input_ids.squeeze(0)

        label = torch.Tensor([self.all_labels[idx]])
        return input_ids, input_ids.size(0), label

# def tokenize_with_pad_truncate(tokenizer, text:str, max_input_length:int):
#     raw_ids = tokenizer.encode(text).ids
#     raw_len = len(raw_ids)
#     if raw_len < max_input_length:
#         # Padding
#         ids = raw_ids + [pad_id]*(max_input_length-raw_len)
#     else:
#         # Truncating
#         ids = raw_ids[:max_input_length]
#     return ids

import torch.nn.utils.rnn as rnn_utils
def collate_fn(batch):
    # input_id, length, label
    batch.sort(key=lambda x: x[1], reverse=True) # sort by sequence length
    sequences, seq_lengths, targets = zip(*batch)

    # Pad the sequences and stack the targets
    sequences_padded = rnn_utils.pad_sequence(sequences, padding_value=pad_id, batch_first=True)
    targets_stacked = torch.stack(targets)

    return sequences_padded, seq_lengths, targets_stacked

batch_size = 64

train_text, train_label = dataset["train"]["text_cleaned"], dataset["train"]["label"]
validation_text, validation_label = dataset["val"]["text_cleaned"], dataset["val"]["label"]
test_text, test_label = dataset["test"]["text_cleaned"], dataset["test"]["label"]

trainset = IMDB50(train_text, train_label, tokenizer)
valset = IMDB50(validation_text, validation_label, tokenizer)
testset = IMDB50(test_text, test_label, tokenizer)

train_loader = torch_data.DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = torch_data.DataLoader(valset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = torch_data.DataLoader(testset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

print(next(iter(test_loader))[0].shape, next(iter(test_loader))[1], next(iter(test_loader))[2].shape)
# Out:
# torch.Size([64, 629]) (629, 588, 568, 541, 519, 437, 423, 411, 392, 359, 357, 355, 321, 292, 285, 266, 261, 247, 247, 238, 232, 230, 226, 226, 220, 219, 217, 203, 201, 199, 196, 194, 191, 190, 189, 187, 176, 173, 171, 170, 168, 164, 159, 154, 153, 150, 147, 138, 135, 133, 130, 128, 125, 124, 123, 121, 105, 75, 74, 57, 53, 51, 32, 21) torch.Size([64, 1])

# %% [markdown]
# ### Model
# Model Class are wrapped in rnn_classifier.py

# %%
import torch, random
import numpy as np
import torch.nn as nn
from tqdm.notebook import tqdm
from sklearn.metrics import classification_report, accuracy_score
from rnn_classifier import RNNBinarySequenceClassifier

class Trainer:

    def __init__(self,
                 exp_name="default",
                 seed=42,
                 device="cuda",
                 info_steps=10,
                 args=None) -> None:

        args.exp_name = exp_name
        args.seed = seed
        args.info_steps = info_steps
        args.device = device

        print("---"*20)
        print("Running Experiment: ", args.exp_name)
        print("---"*20)

        self.args = args
        self.init_train_objects()

    def init_train_objects(self,):

        self.model = RNNBinarySequenceClassifier(
            vocab_size=self.args.vocab_size,
            embedding_size=self.args.embedding_size,
            hidden_size=self.args.hidden_size,
            output_size=self.args.output_size,
            num_layers=self.args.num_layers,
            embedding_dropout=self.args.embedding_dropout,
            output_dropout=self.args.output_dropout,
            rnn_dropout=self.args.rnn_dropout,
            embedding_type=self.args.embedding_type,
            rnn_base_cell=self.args.rnn_base_cell,
            learnable=self.args.embedding_learnable,
            bidirectional=self.args.bidirectional,
            vocab=vocab,
        ).to(self.args.device)

        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.args.lr)
        self.scheduler = None

        self.loss_fc = nn.BCEWithLogitsLoss()

    def train_loop(self, train_loader, progress_bar):

        self.model.train()
        train_loss_per_epoch = 0.0
        train_loss_per_steps = 0.0
        for i, (input_ids, lengths, labels) in enumerate(train_loader):
            input_ids, labels = input_ids.to(self.args.device), labels.to(self.args.device)
            self.optimizer.zero_grad()
            output = self.model((input_ids, lengths))
            loss = self.loss_fc(output, labels)

            train_loss_per_epoch += loss.item()
            train_loss_per_steps += loss.item()
            loss.backward()
            self.optimizer.step()

            progress_bar.update(1)
            if progress_bar.n % self.args.info_steps == 0:
                print(f"Step {progress_bar.n}/{progress_bar.total}: Training Loss={train_loss_per_steps/self.args.info_steps:.5f}")
                train_loss_per_steps = 0.0

        return train_loss_per_epoch/len(train_loader)

    @torch.no_grad()
    def eval_loop(self, loader, cls_report=False):
        self.model.eval()

        pred_labels, true_labels = [], []
        for i, (input_ids, lengths, labels) in enumerate(loader):
            input_ids, labels = input_ids.to(self.args.device), labels.to(self.args.device)
            preds = self.model.predict((input_ids, lengths))

            pred_labels.extend(preds.squeeze(-1).tolist())
            true_labels.extend(labels.squeeze(-1).tolist())

        acc = accuracy_score(true_labels, pred_labels)
        if cls_report:
            print(classification_report(true_labels, pred_labels))
            print("Accuracy: ", round(acc, 6))
        return acc

    def train(self,
              num_epochs=10,
              batch_size=64,
              num_workers=0,
              trainset:torch_data.Dataset=None,
              testset:torch_data.Dataset=None,
              valset:torch_data.Dataset=None,):

        torch.manual_seed(self.args.seed)
        np.random.seed(self.args.seed)
        random.seed(self.args.seed)

        train_loader = torch_data.DataLoader(trainset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn, num_workers=num_workers, pin_memory=True)
        val_loader = torch_data.DataLoader(valset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn, num_workers=num_workers, pin_memory=True)
        test_loader = torch_data.DataLoader(testset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn, num_workers=num_workers, pin_memory=True)

        total_train_steps = len(train_loader) * num_epochs
        print(f"Total Training Steps Per Epoch: {len(train_loader)}")
        progress_bar = tqdm(range(1, total_train_steps), desc="Training Progress")

        best_acc = -1
        for epoch in range(1, num_epochs+1):

            train_loss_per_epoch = self.train_loop(train_loader, progress_bar)
            # train_acc_per_epoch = self.eval_loop(train_loader, cls_report=False)
            val_acc_per_epoch = self.eval_loop(val_loader, cls_report=False)
            print(f"Epoch {epoch} | Training Loss: {train_loss_per_epoch/len(train_loader):.4f}  Accuracy: valset={val_acc_per_epoch:.4f}")

            if val_acc_per_epoch > best_acc:
                torch.save(self.model.state_dict(), f"{self.args.exp_name}_best.pt")
                print(f"Saving Best Model at epoch {epoch}")
                best_acc = val_acc_per_epoch

        self.model.load_state_dict(torch.load(f"{self.args.exp_name}_best.pt", map_location=self.args.device))
        self.eval_loop(train_loader, cls_report=True)
        self.eval_loop(val_loader, cls_report=True)
        self.eval_loop(test_loader, cls_report=True)

class RNN_ARG:
    def __init__(self, lr, vocab_size, embedding_size, hidden_size,
                 output_size=1, num_layers=1, embedding_dropout=0., output_dropout=0., rnn_dropout=.0,
                 rnn_base_cell='vanilla', embedding_type='vanilla', embedding_learnable=True, bidirectional=False) -> None:

        self.lr = lr
        self.vocab_size = vocab_size
        self.embedding_size = embedding_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.num_layers = num_layers
        self.embedding_dropout = embedding_dropout
        self.output_dropout = output_dropout
        self.rnn_dropout = rnn_dropout
        self.rnn_base_cell = rnn_base_cell
        self.embedding_type = embedding_type
        self.embedding_learnable = embedding_learnable
        self.bidirectional = bidirectional

# %% [markdown]
# ## Running Experiments

# %%
import warnings
warnings.filterwarnings("ignore")
import os
os.environ["TOKENIZERS_PARALLELISM"] = "true"

device = "cuda" if torch.cuda.is_available() else "cpu"
seed = 42
device
# Out:
# 'cuda'

# %% [markdown]
# ### Variant 1 [Model Hyper-Parameters]
# For this one, we only tune rnn type as well as hidden_size

# %%
num_layers = 2
output_size = 1
embedding_dropout = .3
output_dropout = .3
rnn_dropout = .3
num_epochs = 12
lr = 1e-3
bs = 64
num_workers=8

# %%
# To Compare the varying effects of hidden size and model types
for hidden_size in [64, 128, 256]:
    for model_type in ["vanilla", "lstm", "gru"]:
        args = RNN_ARG(lr, vocab_size, embedding_size=hidden_size, hidden_size=hidden_size,
                    output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
                    rnn_base_cell=model_type, embedding_type="vanilla", embedding_learnable=True, bidirectional=False, rnn_dropout=rnn_dropout)

        trainer = Trainer(exp_name=f"{model_type}_rnn_{hidden_size}", seed=seed, device=device, args=args, info_steps=100)
        trainer.train(num_epochs, bs, num_workers, trainset, testset, valset)
# Out:
# ------------------------------------------------------------
# Running Experiment:  vanilla_rnn_64
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.69580
# Step 200/3755: Training Loss=0.69016
# Step 300/3755: Training Loss=0.68412
# Epoch 1 | Training Loss: 0.0022  Accuracy: valset=0.5744
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.58195
# Step 500/3755: Training Loss=0.66666
# Step 600/3755: Training Loss=0.65788
# Epoch 2 | Training Loss: 0.0021  Accuracy: valset=0.5874
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.49300
# Step 800/3755: Training Loss=0.64646
# Step 900/3755: Training Loss=0.62870
# Epoch 3 | Training Loss: 0.0021  Accuracy: valset=0.6432
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.37608
# Step 1100/3755: Training Loss=0.60148
# Step 1200/3755: Training Loss=0.66800
# Epoch 4 | Training Loss: 0.0020  Accuracy: valset=0.6304
# Step 1300/3755: Training Loss=0.30711
# Step 1400/3755: Training Loss=0.63681
# Step 1500/3755: Training Loss=0.61737
# Epoch 5 | Training Loss: 0.0020  Accuracy: valset=0.6540
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.21186
# Step 1700/3755: Training Loss=0.58197
# Step 1800/3755: Training Loss=0.60620
# Epoch 6 | Training Loss: 0.0019  Accuracy: valset=0.6868
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.12262
# Step 2000/3755: Training Loss=0.56011
# Step 2100/3755: Training Loss=0.54891
# Epoch 7 | Training Loss: 0.0018  Accuracy: valset=0.7310
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.04471
# Step 2300/3755: Training Loss=0.51706
# Step 2400/3755: Training Loss=0.50589
# Step 2500/3755: Training Loss=0.49843
# Epoch 8 | Training Loss: 0.0016  Accuracy: valset=0.7450
# Saving Best Model at epoch 8
# Step 2600/3755: Training Loss=0.46796
# Step 2700/3755: Training Loss=0.48805
# Step 2800/3755: Training Loss=0.48823
# Epoch 9 | Training Loss: 0.0016  Accuracy: valset=0.7804
# Saving Best Model at epoch 9
# Step 2900/3755: Training Loss=0.39657
# Step 3000/3755: Training Loss=0.47190
# Step 3100/3755: Training Loss=0.57649
# Epoch 10 | Training Loss: 0.0017  Accuracy: valset=0.6470
# Step 3200/3755: Training Loss=0.39131
# Step 3300/3755: Training Loss=0.52123
# Step 3400/3755: Training Loss=0.49596
# Epoch 11 | Training Loss: 0.0017  Accuracy: valset=0.6176
# Step 3500/3755: Training Loss=0.32851
# Step 3600/3755: Training Loss=0.52016
# Step 3700/3755: Training Loss=0.47793
# Epoch 12 | Training Loss: 0.0016  Accuracy: valset=0.7562
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.79      0.81     10000
#          1.0       0.80      0.84      0.82     10000
#
#     accuracy                           0.82     20000
#    macro avg       0.82      0.82      0.82     20000
# weighted avg       0.82      0.82      0.82     20000
#
# Accuracy:  0.8157
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.75      0.77      2500
#          1.0       0.76      0.81      0.79      2500
#
#     accuracy                           0.78      5000
#    macro avg       0.78      0.78      0.78      5000
# weighted avg       0.78      0.78      0.78      5000
#
# Accuracy:  0.7804
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.75      0.77     12500
#          1.0       0.76      0.80      0.78     12500
#
#     accuracy                           0.77     25000
#    macro avg       0.77      0.77      0.77     25000
# weighted avg       0.77      0.77      0.77     25000
#
# Accuracy:  0.77128
# ------------------------------------------------------------
# Running Experiment:  lstm_rnn_64
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.69139
# Step 200/3755: Training Loss=0.65621
# Step 300/3755: Training Loss=0.64408
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.6362
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.54640
# Step 500/3755: Training Loss=0.65291
# Step 600/3755: Training Loss=0.63532
# Epoch 2 | Training Loss: 0.0020  Accuracy: valset=0.6966
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.45496
# Step 800/3755: Training Loss=0.57191
# Step 900/3755: Training Loss=0.54153
# Epoch 3 | Training Loss: 0.0018  Accuracy: valset=0.7646
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.31582
# Step 1100/3755: Training Loss=0.55232
# Step 1200/3755: Training Loss=0.53481
# Epoch 4 | Training Loss: 0.0017  Accuracy: valset=0.7844
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.26432
# Step 1400/3755: Training Loss=0.64779
# Step 1500/3755: Training Loss=0.52959
# Epoch 5 | Training Loss: 0.0018  Accuracy: valset=0.8008
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.16364
# Step 1700/3755: Training Loss=0.42940
# Step 1800/3755: Training Loss=0.41514
# Epoch 6 | Training Loss: 0.0014  Accuracy: valset=0.8304
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.07905
# Step 2000/3755: Training Loss=0.36005
# Step 2100/3755: Training Loss=0.34739
# Epoch 7 | Training Loss: 0.0011  Accuracy: valset=0.8372
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.02588
# Step 2300/3755: Training Loss=0.30566
# Step 2400/3755: Training Loss=0.29565
# Step 2500/3755: Training Loss=0.29886
# Epoch 8 | Training Loss: 0.0010  Accuracy: valset=0.8594
# Saving Best Model at epoch 8
# Step 2600/3755: Training Loss=0.25381
# Step 2700/3755: Training Loss=0.26512
# Step 2800/3755: Training Loss=0.24954
# Epoch 9 | Training Loss: 0.0008  Accuracy: valset=0.8696
# Saving Best Model at epoch 9
# Step 2900/3755: Training Loss=0.19259
# Step 3000/3755: Training Loss=0.22815
# Step 3100/3755: Training Loss=0.21725
# Epoch 10 | Training Loss: 0.0007  Accuracy: valset=0.8750
# Saving Best Model at epoch 10
# Step 3200/3755: Training Loss=0.13697
# Step 3300/3755: Training Loss=0.19365
# Step 3400/3755: Training Loss=0.20717
# Epoch 11 | Training Loss: 0.0006  Accuracy: valset=0.8776
# Saving Best Model at epoch 11
# Step 3500/3755: Training Loss=0.10282
# Step 3600/3755: Training Loss=0.18124
# Step 3700/3755: Training Loss=0.19190
# Epoch 12 | Training Loss: 0.0006  Accuracy: valset=0.8844
# Saving Best Model at epoch 12
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97     10000
#          1.0       0.96      0.97      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
#
# Accuracy:  0.9656
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.87      0.88      2500
#          1.0       0.87      0.90      0.89      2500
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.88      0.88      5000
# weighted avg       0.88      0.88      0.88      5000
#
# Accuracy:  0.8844
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.88     12500
#          1.0       0.87      0.88      0.88     12500
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.88     25000
# weighted avg       0.88      0.88      0.88     25000
#
# Accuracy:  0.87892
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_64
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.68857
# Step 200/3755: Training Loss=0.66654
# Step 300/3755: Training Loss=0.64141
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.6848
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.51328
# Step 500/3755: Training Loss=0.58364
# Step 600/3755: Training Loss=0.55777
# Epoch 2 | Training Loss: 0.0018  Accuracy: valset=0.7888
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.34240
# Step 800/3755: Training Loss=0.42295
# Step 900/3755: Training Loss=0.41348
# Epoch 3 | Training Loss: 0.0013  Accuracy: valset=0.8128
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.21967
# Step 1100/3755: Training Loss=0.32539
# Step 1200/3755: Training Loss=0.31012
# Epoch 4 | Training Loss: 0.0010  Accuracy: valset=0.8596
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.13535
# Step 1400/3755: Training Loss=0.27047
# Step 1500/3755: Training Loss=0.26582
# Epoch 5 | Training Loss: 0.0009  Accuracy: valset=0.8794
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.08428
# Step 1700/3755: Training Loss=0.22437
# Step 1800/3755: Training Loss=0.22327
# Epoch 6 | Training Loss: 0.0007  Accuracy: valset=0.8640
# Step 1900/3755: Training Loss=0.04495
# Step 2000/3755: Training Loss=0.19582
# Step 2100/3755: Training Loss=0.20325
# Epoch 7 | Training Loss: 0.0006  Accuracy: valset=0.8612
# Step 2200/3755: Training Loss=0.01395
# Step 2300/3755: Training Loss=0.17394
# Step 2400/3755: Training Loss=0.16468
# Step 2500/3755: Training Loss=0.17611
# Epoch 8 | Training Loss: 0.0005  Accuracy: valset=0.8944
# Saving Best Model at epoch 8
# Step 2600/3755: Training Loss=0.14757
# Step 2700/3755: Training Loss=0.14924
# Step 2800/3755: Training Loss=0.13713
# Epoch 9 | Training Loss: 0.0005  Accuracy: valset=0.8876
# Step 2900/3755: Training Loss=0.10535
# Step 3000/3755: Training Loss=0.12918
# Step 3100/3755: Training Loss=0.12363
# Epoch 10 | Training Loss: 0.0004  Accuracy: valset=0.8798
# Step 3200/3755: Training Loss=0.07557
# Step 3300/3755: Training Loss=0.11049
# Step 3400/3755: Training Loss=0.13107
# Epoch 11 | Training Loss: 0.0004  Accuracy: valset=0.8708
# Step 3500/3755: Training Loss=0.06235
# Step 3600/3755: Training Loss=0.09717
# Step 3700/3755: Training Loss=0.10388
# Epoch 12 | Training Loss: 0.0003  Accuracy: valset=0.8840
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97     10000
#          1.0       0.97      0.97      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
#
# Accuracy:  0.9741
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.89      0.89      2500
#          1.0       0.89      0.90      0.90      2500
#
#     accuracy                           0.89      5000
#    macro avg       0.89      0.89      0.89      5000
# weighted avg       0.89      0.89      0.89      5000
#
# Accuracy:  0.8944
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.89     12500
#          1.0       0.89      0.88      0.89     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.8874
# ------------------------------------------------------------
# Running Experiment:  vanilla_rnn_128
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.69099
# Step 200/3755: Training Loss=0.67323
# Step 300/3755: Training Loss=0.65786
# Epoch 1 | Training Loss: 0.0022  Accuracy: valset=0.5584
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.55935
# Step 500/3755: Training Loss=0.65332
# Step 600/3755: Training Loss=0.63646
# Epoch 2 | Training Loss: 0.0021  Accuracy: valset=0.6764
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.46063
# Step 800/3755: Training Loss=0.62223
# Step 900/3755: Training Loss=0.60731
# Epoch 3 | Training Loss: 0.0020  Accuracy: valset=0.5710
# Step 1000/3755: Training Loss=0.36622
# Step 1100/3755: Training Loss=0.59949
# Step 1200/3755: Training Loss=0.58768
# Epoch 4 | Training Loss: 0.0019  Accuracy: valset=0.6952
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.27457
# Step 1400/3755: Training Loss=0.60059
# Step 1500/3755: Training Loss=0.58146
# Epoch 5 | Training Loss: 0.0019  Accuracy: valset=0.6824
# Step 1600/3755: Training Loss=0.20038
# Step 1700/3755: Training Loss=0.54446
# Step 1800/3755: Training Loss=0.51689
# Epoch 6 | Training Loss: 0.0017  Accuracy: valset=0.7714
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.10313
# Step 2000/3755: Training Loss=0.48941
# Step 2100/3755: Training Loss=0.51285
# Epoch 7 | Training Loss: 0.0016  Accuracy: valset=0.7378
# Step 2200/3755: Training Loss=0.04429
# Step 2300/3755: Training Loss=0.49315
# Step 2400/3755: Training Loss=0.51622
# Step 2500/3755: Training Loss=0.51567
# Epoch 8 | Training Loss: 0.0016  Accuracy: valset=0.6330
# Step 2600/3755: Training Loss=0.54937
# Step 2700/3755: Training Loss=0.49681
# Step 2800/3755: Training Loss=0.47025
# Epoch 9 | Training Loss: 0.0016  Accuracy: valset=0.6762
# Step 2900/3755: Training Loss=0.42963
# Step 3000/3755: Training Loss=0.42671
# Step 3100/3755: Training Loss=0.44626
# Epoch 10 | Training Loss: 0.0015  Accuracy: valset=0.7750
# Saving Best Model at epoch 10
# Step 3200/3755: Training Loss=0.29386
# Step 3300/3755: Training Loss=0.41785
# Step 3400/3755: Training Loss=0.42501
# Epoch 11 | Training Loss: 0.0013  Accuracy: valset=0.8008
# Saving Best Model at epoch 11
# Step 3500/3755: Training Loss=0.21759
# Step 3600/3755: Training Loss=0.39997
# Step 3700/3755: Training Loss=0.40910
# Epoch 12 | Training Loss: 0.0013  Accuracy: valset=0.7740
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.82      0.84     10000
#          1.0       0.83      0.86      0.85     10000
#
#     accuracy                           0.84     20000
#    macro avg       0.84      0.84      0.84     20000
# weighted avg       0.84      0.84      0.84     20000
#
# Accuracy:  0.842
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.77      0.79      2500
#          1.0       0.78      0.83      0.81      2500
#
#     accuracy                           0.80      5000
#    macro avg       0.80      0.80      0.80      5000
# weighted avg       0.80      0.80      0.80      5000
#
# Accuracy:  0.8008
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.76      0.79     12500
#          1.0       0.77      0.83      0.80     12500
#
#     accuracy                           0.79     25000
#    macro avg       0.79      0.79      0.79     25000
# weighted avg       0.79      0.79      0.79     25000
#
# Accuracy:  0.79264
# ------------------------------------------------------------
# Running Experiment:  lstm_rnn_128
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.67712
# Step 200/3755: Training Loss=0.62717
# Step 300/3755: Training Loss=0.58946
# Epoch 1 | Training Loss: 0.0020  Accuracy: valset=0.6724
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.49706
# Step 500/3755: Training Loss=0.56688
# Step 600/3755: Training Loss=0.53202
# Epoch 2 | Training Loss: 0.0018  Accuracy: valset=0.7300
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.37226
# Step 800/3755: Training Loss=0.48668
# Step 900/3755: Training Loss=0.46953
# Epoch 3 | Training Loss: 0.0016  Accuracy: valset=0.5070
# Step 1000/3755: Training Loss=0.42451
# Step 1100/3755: Training Loss=0.68086
# Step 1200/3755: Training Loss=0.64275
# Epoch 4 | Training Loss: 0.0021  Accuracy: valset=0.7924
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.23474
# Step 1400/3755: Training Loss=0.60567
# Step 1500/3755: Training Loss=0.58509
# Epoch 5 | Training Loss: 0.0019  Accuracy: valset=0.6698
# Step 1600/3755: Training Loss=0.20618
# Step 1700/3755: Training Loss=0.49270
# Step 1800/3755: Training Loss=0.44118
# Epoch 6 | Training Loss: 0.0015  Accuracy: valset=0.7928
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.08554
# Step 2000/3755: Training Loss=0.33511
# Step 2100/3755: Training Loss=0.33314
# Epoch 7 | Training Loss: 0.0011  Accuracy: valset=0.8428
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.02347
# Step 2300/3755: Training Loss=0.33134
# Step 2400/3755: Training Loss=0.29910
# Step 2500/3755: Training Loss=0.29755
# Epoch 8 | Training Loss: 0.0010  Accuracy: valset=0.8630
# Saving Best Model at epoch 8
# Step 2600/3755: Training Loss=0.23742
# Step 2700/3755: Training Loss=0.24340
# Step 2800/3755: Training Loss=0.22853
# Epoch 9 | Training Loss: 0.0008  Accuracy: valset=0.8700
# Saving Best Model at epoch 9
# Step 2900/3755: Training Loss=0.16495
# Step 3000/3755: Training Loss=0.24462
# Step 3100/3755: Training Loss=0.25537
# Epoch 10 | Training Loss: 0.0007  Accuracy: valset=0.8726
# Saving Best Model at epoch 10
# Step 3200/3755: Training Loss=0.14301
# Step 3300/3755: Training Loss=0.19346
# Step 3400/3755: Training Loss=0.23003
# Epoch 11 | Training Loss: 0.0007  Accuracy: valset=0.8800
# Saving Best Model at epoch 11
# Step 3500/3755: Training Loss=0.10151
# Step 3600/3755: Training Loss=0.16710
# Step 3700/3755: Training Loss=0.16956
# Epoch 12 | Training Loss: 0.0005  Accuracy: valset=0.8820
# Saving Best Model at epoch 12
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.96      0.97     10000
#          1.0       0.96      0.97      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
#
# Accuracy:  0.9653
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.86      0.88      2500
#          1.0       0.86      0.91      0.88      2500
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.88      0.88      5000
# weighted avg       0.88      0.88      0.88      5000
#
# Accuracy:  0.882
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.86      0.87     12500
#          1.0       0.86      0.89      0.88     12500
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.87     25000
# weighted avg       0.88      0.88      0.87     25000
#
# Accuracy:  0.875
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_128
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.67504
# Step 200/3755: Training Loss=0.64482
# Step 300/3755: Training Loss=0.61098
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.7394
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.44796
# Step 500/3755: Training Loss=0.49277
# Step 600/3755: Training Loss=0.41822
# Epoch 2 | Training Loss: 0.0015  Accuracy: valset=0.8364
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.27027
# Step 800/3755: Training Loss=0.32467
# Step 900/3755: Training Loss=0.31235
# Epoch 3 | Training Loss: 0.0010  Accuracy: valset=0.8358
# Step 1000/3755: Training Loss=0.16570
# Step 1100/3755: Training Loss=0.25573
# Step 1200/3755: Training Loss=0.23668
# Epoch 4 | Training Loss: 0.0008  Accuracy: valset=0.8750
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.09647
# Step 1400/3755: Training Loss=0.19263
# Step 1500/3755: Training Loss=0.19651
# Epoch 5 | Training Loss: 0.0006  Accuracy: valset=0.8778
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.05962
# Step 1700/3755: Training Loss=0.15766
# Step 1800/3755: Training Loss=0.16225
# Epoch 6 | Training Loss: 0.0005  Accuracy: valset=0.8826
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.02898
# Step 2000/3755: Training Loss=0.12728
# Step 2100/3755: Training Loss=0.13100
# Epoch 7 | Training Loss: 0.0004  Accuracy: valset=0.8838
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.00835
# Step 2300/3755: Training Loss=0.09313
# Step 2400/3755: Training Loss=0.10093
# Step 2500/3755: Training Loss=0.11679
# Epoch 8 | Training Loss: 0.0003  Accuracy: valset=0.8824
# Step 2600/3755: Training Loss=0.08591
# Step 2700/3755: Training Loss=0.09128
# Step 2800/3755: Training Loss=0.09257
# Epoch 9 | Training Loss: 0.0003  Accuracy: valset=0.8980
# Saving Best Model at epoch 9
# Step 2900/3755: Training Loss=0.05299
# Step 3000/3755: Training Loss=0.06490
# Step 3100/3755: Training Loss=0.07466
# Epoch 10 | Training Loss: 0.0002  Accuracy: valset=0.8838
# Step 3200/3755: Training Loss=0.03623
# Step 3300/3755: Training Loss=0.05672
# Step 3400/3755: Training Loss=0.06901
# Epoch 11 | Training Loss: 0.0002  Accuracy: valset=0.8876
# Step 3500/3755: Training Loss=0.03097
# Step 3600/3755: Training Loss=0.04664
# Step 3700/3755: Training Loss=0.05684
# Epoch 12 | Training Loss: 0.0002  Accuracy: valset=0.8900
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99     10000
#          1.0       0.99      0.99      0.99     10000
#
#     accuracy                           0.99     20000
#    macro avg       0.99      0.99      0.99     20000
# weighted avg       0.99      0.99      0.99     20000
#
# Accuracy:  0.99335
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.88      0.90      2500
#          1.0       0.88      0.92      0.90      2500
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
# Accuracy:  0.898
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89     12500
#          1.0       0.88      0.90      0.89     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.88888
# ------------------------------------------------------------
# Running Experiment:  vanilla_rnn_256
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.69720
# Step 200/3755: Training Loss=0.68140
# Step 300/3755: Training Loss=0.68512
# Epoch 1 | Training Loss: 0.0022  Accuracy: valset=0.5764
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.57284
# Step 500/3755: Training Loss=0.64858
# Step 600/3755: Training Loss=0.64089
# Epoch 2 | Training Loss: 0.0021  Accuracy: valset=0.6692
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.45591
# Step 800/3755: Training Loss=0.60799
# Step 900/3755: Training Loss=0.60766
# Epoch 3 | Training Loss: 0.0019  Accuracy: valset=0.6060
# Step 1000/3755: Training Loss=0.35694
# Step 1100/3755: Training Loss=0.56513
# Step 1200/3755: Training Loss=0.54761
# Epoch 4 | Training Loss: 0.0018  Accuracy: valset=0.7198
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.25727
# Step 1400/3755: Training Loss=0.50315
# Step 1500/3755: Training Loss=0.48330
# Epoch 5 | Training Loss: 0.0016  Accuracy: valset=0.6412
# Step 1600/3755: Training Loss=0.19479
# Step 1700/3755: Training Loss=0.49598
# Step 1800/3755: Training Loss=0.52427
# Epoch 6 | Training Loss: 0.0017  Accuracy: valset=0.7540
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.09742
# Step 2000/3755: Training Loss=0.43604
# Step 2100/3755: Training Loss=0.45675
# Epoch 7 | Training Loss: 0.0016  Accuracy: valset=0.5166
# Step 2200/3755: Training Loss=0.06267
# Step 2300/3755: Training Loss=0.69480
# Step 2400/3755: Training Loss=0.68833
# Step 2500/3755: Training Loss=0.67190
# Epoch 8 | Training Loss: 0.0022  Accuracy: valset=0.5774
# Step 2600/3755: Training Loss=0.62292
# Step 2700/3755: Training Loss=0.62261
# Step 2800/3755: Training Loss=0.60433
# Epoch 9 | Training Loss: 0.0020  Accuracy: valset=0.6882
# Step 2900/3755: Training Loss=0.48010
# Step 3000/3755: Training Loss=0.57213
# Step 3100/3755: Training Loss=0.56007
# Epoch 10 | Training Loss: 0.0018  Accuracy: valset=0.6992
# Step 3200/3755: Training Loss=0.36935
# Step 3300/3755: Training Loss=0.50633
# Step 3400/3755: Training Loss=0.50953
# Epoch 11 | Training Loss: 0.0016  Accuracy: valset=0.7380
# Step 3500/3755: Training Loss=0.27761
# Step 3600/3755: Training Loss=0.50062
# Step 3700/3755: Training Loss=0.48968
# Epoch 12 | Training Loss: 0.0016  Accuracy: valset=0.6974
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.80      0.82     10000
#          1.0       0.81      0.83      0.82     10000
#
#     accuracy                           0.82     20000
#    macro avg       0.82      0.82      0.82     20000
# weighted avg       0.82      0.82      0.82     20000
#
# Accuracy:  0.8189
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.73      0.75      2500
#          1.0       0.74      0.77      0.76      2500
#
#     accuracy                           0.75      5000
#    macro avg       0.75      0.75      0.75      5000
# weighted avg       0.75      0.75      0.75      5000
#
# Accuracy:  0.754
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.73      0.74     12500
#          1.0       0.74      0.77      0.75     12500
#
#     accuracy                           0.75     25000
#    macro avg       0.75      0.75      0.75     25000
# weighted avg       0.75      0.75      0.75     25000
#
# Accuracy:  0.74564
# ------------------------------------------------------------
# Running Experiment:  lstm_rnn_256
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.69515
# Step 200/3755: Training Loss=0.66054
# Step 300/3755: Training Loss=0.62079
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.7468
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.46234
# Step 500/3755: Training Loss=0.49407
# Step 600/3755: Training Loss=0.45434
# Epoch 2 | Training Loss: 0.0015  Accuracy: valset=0.8270
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.29441
# Step 800/3755: Training Loss=0.34887
# Step 900/3755: Training Loss=0.34632
# Epoch 3 | Training Loss: 0.0011  Accuracy: valset=0.8392
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.18734
# Step 1100/3755: Training Loss=0.27120
# Step 1200/3755: Training Loss=0.33891
# Epoch 4 | Training Loss: 0.0010  Accuracy: valset=0.8646
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.11281
# Step 1400/3755: Training Loss=0.25712
# Step 1500/3755: Training Loss=0.24149
# Epoch 5 | Training Loss: 0.0008  Accuracy: valset=0.8806
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.07130
# Step 1700/3755: Training Loss=0.18422
# Step 1800/3755: Training Loss=0.17457
# Epoch 6 | Training Loss: 0.0006  Accuracy: valset=0.8824
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.03448
# Step 2000/3755: Training Loss=0.13958
# Step 2100/3755: Training Loss=0.14946
# Epoch 7 | Training Loss: 0.0005  Accuracy: valset=0.8918
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.01172
# Step 2300/3755: Training Loss=0.11860
# Step 2400/3755: Training Loss=0.12416
# Step 2500/3755: Training Loss=0.11572
# Epoch 8 | Training Loss: 0.0004  Accuracy: valset=0.8872
# Step 2600/3755: Training Loss=0.08197
# Step 2700/3755: Training Loss=0.08736
# Step 2800/3755: Training Loss=0.07651
# Epoch 9 | Training Loss: 0.0003  Accuracy: valset=0.8918
# Step 2900/3755: Training Loss=0.05010
# Step 3000/3755: Training Loss=0.06981
# Step 3100/3755: Training Loss=0.06601
# Epoch 10 | Training Loss: 0.0002  Accuracy: valset=0.8918
# Step 3200/3755: Training Loss=0.03833
# Step 3300/3755: Training Loss=0.05038
# Step 3400/3755: Training Loss=0.05837
# Epoch 11 | Training Loss: 0.0002  Accuracy: valset=0.8930
# Saving Best Model at epoch 11
# Step 3500/3755: Training Loss=0.02189
# Step 3600/3755: Training Loss=0.04541
# Step 3700/3755: Training Loss=0.04340
# Epoch 12 | Training Loss: 0.0001  Accuracy: valset=0.8910
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     10000
#          1.0       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000
#
# Accuracy:  0.9974
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.89      2500
#          1.0       0.89      0.89      0.89      2500
#
#     accuracy                           0.89      5000
#    macro avg       0.89      0.89      0.89      5000
# weighted avg       0.89      0.89      0.89      5000
#
# Accuracy:  0.893
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.89      0.89     12500
#          1.0       0.89      0.87      0.88     12500
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.88     25000
# weighted avg       0.88      0.88      0.88     25000
#
# Accuracy:  0.8842
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_256
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.67576
# Step 200/3755: Training Loss=0.62883
# Step 300/3755: Training Loss=0.58986
# Epoch 1 | Training Loss: 0.0020  Accuracy: valset=0.7620
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.37815
# Step 500/3755: Training Loss=0.36916
# Step 600/3755: Training Loss=0.32596
# Epoch 2 | Training Loss: 0.0012  Accuracy: valset=0.8742
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.18203
# Step 800/3755: Training Loss=0.22958
# Step 900/3755: Training Loss=0.23785
# Epoch 3 | Training Loss: 0.0008  Accuracy: valset=0.8752
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.10776
# Step 1100/3755: Training Loss=0.16342
# Step 1200/3755: Training Loss=0.15495
# Epoch 4 | Training Loss: 0.0005  Accuracy: valset=0.9010
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.04950
# Step 1400/3755: Training Loss=0.10650
# Step 1500/3755: Training Loss=0.11883
# Epoch 5 | Training Loss: 0.0004  Accuracy: valset=0.8988
# Step 1600/3755: Training Loss=0.02547
# Step 1700/3755: Training Loss=0.08283
# Step 1800/3755: Training Loss=0.08610
# Epoch 6 | Training Loss: 0.0003  Accuracy: valset=0.8778
# Step 1900/3755: Training Loss=0.01454
# Step 2000/3755: Training Loss=0.05011
# Step 2100/3755: Training Loss=0.05599
# Epoch 7 | Training Loss: 0.0002  Accuracy: valset=0.8984
# Step 2200/3755: Training Loss=0.00218
# Step 2300/3755: Training Loss=0.03369
# Step 2400/3755: Training Loss=0.04709
# Step 2500/3755: Training Loss=0.04322
# Epoch 8 | Training Loss: 0.0001  Accuracy: valset=0.8944
# Step 2600/3755: Training Loss=0.02774
# Step 2700/3755: Training Loss=0.04118
# Step 2800/3755: Training Loss=0.03436
# Epoch 9 | Training Loss: 0.0001  Accuracy: valset=0.8966
# Step 2900/3755: Training Loss=0.02232
# Step 3000/3755: Training Loss=0.02888
# Step 3100/3755: Training Loss=0.03172
# Epoch 10 | Training Loss: 0.0001  Accuracy: valset=0.8890
# Step 3200/3755: Training Loss=0.01595
# Step 3300/3755: Training Loss=0.02456
# Step 3400/3755: Training Loss=0.03278
# Epoch 11 | Training Loss: 0.0001  Accuracy: valset=0.8978
# Step 3500/3755: Training Loss=0.01137
# Step 3600/3755: Training Loss=0.01899
# Step 3700/3755: Training Loss=0.02105
# Epoch 12 | Training Loss: 0.0001  Accuracy: valset=0.8876
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.99      0.98     10000
#          1.0       0.98      0.97      0.98     10000
#
#     accuracy                           0.98     20000
#    macro avg       0.98      0.98      0.98     20000
# weighted avg       0.98      0.98      0.98     20000
#
# Accuracy:  0.9779
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90      2500
#          1.0       0.91      0.89      0.90      2500
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
# Accuracy:  0.901
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89     12500
#          1.0       0.90      0.88      0.89     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.8916

# %%
# To Compare the varying effects of bi-directional
for hidden_size in [64, 128, 256]:
    args = RNN_ARG(lr, vocab_size, embedding_size=hidden_size, hidden_size=hidden_size,
                output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
                rnn_base_cell="gru", embedding_type="vanilla", embedding_learnable=True, bidirectional=True, rnn_dropout=rnn_dropout)

    trainer = Trainer(exp_name=f"gru_bi_rnn_{hidden_size}", seed=seed, device=device, args=args, info_steps=50)
    trainer.train(num_epochs, bs, num_workers, trainset, testset, valset)
# Out:
# ------------------------------------------------------------
# Running Experiment:  gru_bi_rnn_64
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 50/3755: Training Loss=0.68589
# Step 100/3755: Training Loss=0.68212
# Step 150/3755: Training Loss=0.66587
# Step 200/3755: Training Loss=0.64652
# Step 250/3755: Training Loss=0.63398
# Step 300/3755: Training Loss=0.59791
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.7156
# Saving Best Model at epoch 1
# Step 350/3755: Training Loss=0.41308
# Step 400/3755: Training Loss=0.55496
# Step 450/3755: Training Loss=0.55145
# Step 500/3755: Training Loss=0.51386
# Step 550/3755: Training Loss=0.51122
# Step 600/3755: Training Loss=0.46855
# Epoch 2 | Training Loss: 0.0017  Accuracy: valset=0.7344
# Saving Best Model at epoch 2
# Step 650/3755: Training Loss=0.22734
# Step 700/3755: Training Loss=0.42649
# Step 750/3755: Training Loss=0.39193
# Step 800/3755: Training Loss=0.38982
# Step 850/3755: Training Loss=0.37540
# Step 900/3755: Training Loss=0.36829
# Epoch 3 | Training Loss: 0.0012  Accuracy: valset=0.8472
# Saving Best Model at epoch 3
# Step 950/3755: Training Loss=0.08240
# Step 1000/3755: Training Loss=0.32018
# Step 1050/3755: Training Loss=0.31901
# Step 1100/3755: Training Loss=0.31311
# Step 1150/3755: Training Loss=0.30230
# Step 1200/3755: Training Loss=0.30948
# Step 1250/3755: Training Loss=0.30254
# Epoch 4 | Training Loss: 0.0010  Accuracy: valset=0.8706
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.26703
# Step 1350/3755: Training Loss=0.26317
# Step 1400/3755: Training Loss=0.26901
# Step 1450/3755: Training Loss=0.23754
# Step 1500/3755: Training Loss=0.27049
# Step 1550/3755: Training Loss=0.26936
# Epoch 5 | Training Loss: 0.0008  Accuracy: valset=0.8812
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.15857
# Step 1650/3755: Training Loss=0.21055
# Step 1700/3755: Training Loss=0.22630
# Step 1750/3755: Training Loss=0.22097
# Step 1800/3755: Training Loss=0.22090
# Step 1850/3755: Training Loss=0.22274
# Epoch 6 | Training Loss: 0.0007  Accuracy: valset=0.8698
# Step 1900/3755: Training Loss=0.08211
# Step 1950/3755: Training Loss=0.20982
# Step 2000/3755: Training Loss=0.17694
# Step 2050/3755: Training Loss=0.19764
# Step 2100/3755: Training Loss=0.19552
# Step 2150/3755: Training Loss=0.18636
# Epoch 7 | Training Loss: 0.0006  Accuracy: valset=0.8704
# Step 2200/3755: Training Loss=0.02849
# Step 2250/3755: Training Loss=0.17038
# Step 2300/3755: Training Loss=0.15822
# Step 2350/3755: Training Loss=0.15284
# Step 2400/3755: Training Loss=0.17326
# Step 2450/3755: Training Loss=0.18136
# Step 2500/3755: Training Loss=0.15869
# Epoch 8 | Training Loss: 0.0005  Accuracy: valset=0.8928
# Saving Best Model at epoch 8
# Step 2550/3755: Training Loss=0.12630
# Step 2600/3755: Training Loss=0.14580
# Step 2650/3755: Training Loss=0.14347
# Step 2700/3755: Training Loss=0.15308
# Step 2750/3755: Training Loss=0.14300
# Step 2800/3755: Training Loss=0.12524
# Epoch 9 | Training Loss: 0.0005  Accuracy: valset=0.8780
# Step 2850/3755: Training Loss=0.08147
# Step 2900/3755: Training Loss=0.11725
# Step 2950/3755: Training Loss=0.12291
# Step 3000/3755: Training Loss=0.12093
# Step 3050/3755: Training Loss=0.11130
# Step 3100/3755: Training Loss=0.11976
# Epoch 10 | Training Loss: 0.0004  Accuracy: valset=0.8926
# Step 3150/3755: Training Loss=0.04259
# Step 3200/3755: Training Loss=0.10137
# Step 3250/3755: Training Loss=0.09420
# Step 3300/3755: Training Loss=0.11641
# Step 3350/3755: Training Loss=0.12783
# Step 3400/3755: Training Loss=0.13179
# Epoch 11 | Training Loss: 0.0004  Accuracy: valset=0.8676
# Step 3450/3755: Training Loss=0.01163
# Step 3500/3755: Training Loss=0.08879
# Step 3550/3755: Training Loss=0.08283
# Step 3600/3755: Training Loss=0.10235
# Step 3650/3755: Training Loss=0.10737
# Step 3700/3755: Training Loss=0.09517
# Step 3750/3755: Training Loss=0.10765
# Epoch 12 | Training Loss: 0.0003  Accuracy: valset=0.8856
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.97     10000
#          1.0       0.97      0.98      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000
#
# Accuracy:  0.9729
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89      2500
#          1.0       0.87      0.92      0.90      2500
#
#     accuracy                           0.89      5000
#    macro avg       0.89      0.89      0.89      5000
# weighted avg       0.89      0.89      0.89      5000
#
# Accuracy:  0.8928
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.87      0.89     12500
#          1.0       0.87      0.91      0.89     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.88732
# ------------------------------------------------------------
# Running Experiment:  gru_bi_rnn_128
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 50/3755: Training Loss=0.68713
# Step 100/3755: Training Loss=0.66217
# Step 150/3755: Training Loss=0.65991
# Step 200/3755: Training Loss=0.61877
# Step 250/3755: Training Loss=0.58338
# Step 300/3755: Training Loss=0.55345
# Epoch 1 | Training Loss: 0.0020  Accuracy: valset=0.6196
# Saving Best Model at epoch 1
# Step 350/3755: Training Loss=0.37786
# Step 400/3755: Training Loss=0.55523
# Step 450/3755: Training Loss=0.54099
# Step 500/3755: Training Loss=0.48957
# Step 550/3755: Training Loss=0.44515
# Step 600/3755: Training Loss=0.40770
# Epoch 2 | Training Loss: 0.0015  Accuracy: valset=0.7700
# Saving Best Model at epoch 2
# Step 650/3755: Training Loss=0.17119
# Step 700/3755: Training Loss=0.35748
# Step 750/3755: Training Loss=0.33881
# Step 800/3755: Training Loss=0.32846
# Step 850/3755: Training Loss=0.33299
# Step 900/3755: Training Loss=0.30844
# Epoch 3 | Training Loss: 0.0011  Accuracy: valset=0.8738
# Saving Best Model at epoch 3
# Step 950/3755: Training Loss=0.06235
# Step 1000/3755: Training Loss=0.26074
# Step 1050/3755: Training Loss=0.25602
# Step 1100/3755: Training Loss=0.25154
# Step 1150/3755: Training Loss=0.22868
# Step 1200/3755: Training Loss=0.24224
# Step 1250/3755: Training Loss=0.24458
# Epoch 4 | Training Loss: 0.0008  Accuracy: valset=0.8852
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.19010
# Step 1350/3755: Training Loss=0.18477
# Step 1400/3755: Training Loss=0.20216
# Step 1450/3755: Training Loss=0.17759
# Step 1500/3755: Training Loss=0.20645
# Step 1550/3755: Training Loss=0.18643
# Epoch 5 | Training Loss: 0.0006  Accuracy: valset=0.8838
# Step 1600/3755: Training Loss=0.10930
# Step 1650/3755: Training Loss=0.15753
# Step 1700/3755: Training Loss=0.15151
# Step 1750/3755: Training Loss=0.15143
# Step 1800/3755: Training Loss=0.15337
# Step 1850/3755: Training Loss=0.15198
# Epoch 6 | Training Loss: 0.0005  Accuracy: valset=0.8964
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.05163
# Step 1950/3755: Training Loss=0.12421
# Step 2000/3755: Training Loss=0.11229
# Step 2050/3755: Training Loss=0.13761
# Step 2100/3755: Training Loss=0.11798
# Step 2150/3755: Training Loss=0.13682
# Epoch 7 | Training Loss: 0.0004  Accuracy: valset=0.8930
# Step 2200/3755: Training Loss=0.01870
# Step 2250/3755: Training Loss=0.09215
# Step 2300/3755: Training Loss=0.08954
# Step 2350/3755: Training Loss=0.10637
# Step 2400/3755: Training Loss=0.10684
# Step 2450/3755: Training Loss=0.10590
# Step 2500/3755: Training Loss=0.09996
# Epoch 8 | Training Loss: 0.0003  Accuracy: valset=0.8986
# Saving Best Model at epoch 8
# Step 2550/3755: Training Loss=0.07775
# Step 2600/3755: Training Loss=0.08803
# Step 2650/3755: Training Loss=0.08692
# Step 2700/3755: Training Loss=0.07627
# Step 2750/3755: Training Loss=0.09116
# Step 2800/3755: Training Loss=0.09580
# Epoch 9 | Training Loss: 0.0003  Accuracy: valset=0.8952
# Step 2850/3755: Training Loss=0.05434
# Step 2900/3755: Training Loss=0.05022
# Step 2950/3755: Training Loss=0.06029
# Step 3000/3755: Training Loss=0.06187
# Step 3050/3755: Training Loss=0.06749
# Step 3100/3755: Training Loss=0.06773
# Epoch 10 | Training Loss: 0.0002  Accuracy: valset=0.8994
# Saving Best Model at epoch 10
# Step 3150/3755: Training Loss=0.01470
# Step 3200/3755: Training Loss=0.04190
# Step 3250/3755: Training Loss=0.05101
# Step 3300/3755: Training Loss=0.05576
# Step 3350/3755: Training Loss=0.05202
# Step 3400/3755: Training Loss=0.06450
# Epoch 11 | Training Loss: 0.0002  Accuracy: valset=0.8800
# Step 3450/3755: Training Loss=0.00696
# Step 3500/3755: Training Loss=0.04796
# Step 3550/3755: Training Loss=0.04524
# Step 3600/3755: Training Loss=0.04041
# Step 3650/3755: Training Loss=0.03925
# Step 3700/3755: Training Loss=0.04176
# Step 3750/3755: Training Loss=0.04082
# Epoch 12 | Training Loss: 0.0001  Accuracy: valset=0.8970
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     10000
#          1.0       1.00      0.99      1.00     10000
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000
#
# Accuracy:  0.9964
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90      2500
#          1.0       0.90      0.90      0.90      2500
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
# Accuracy:  0.8994
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89     12500
#          1.0       0.90      0.87      0.88     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.88508
# ------------------------------------------------------------
# Running Experiment:  gru_bi_rnn_256
# ------------------------------------------------------------
# Random Initialize
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 50/3755: Training Loss=0.68296
# Step 100/3755: Training Loss=0.63630
# Step 150/3755: Training Loss=0.62069
# Step 200/3755: Training Loss=0.57384
# Step 250/3755: Training Loss=0.55312
# Step 300/3755: Training Loss=0.61416
# Epoch 1 | Training Loss: 0.0019  Accuracy: valset=0.7732
# Saving Best Model at epoch 1
# Step 350/3755: Training Loss=0.34154
# Step 400/3755: Training Loss=0.41140
# Step 450/3755: Training Loss=0.38034
# Step 500/3755: Training Loss=0.35131
# Step 550/3755: Training Loss=0.33774
# Step 600/3755: Training Loss=0.32373
# Epoch 2 | Training Loss: 0.0012  Accuracy: valset=0.8592
# Saving Best Model at epoch 2
# Step 650/3755: Training Loss=0.12677
# Step 700/3755: Training Loss=0.24836
# Step 750/3755: Training Loss=0.22698
# Step 800/3755: Training Loss=0.23887
# Step 850/3755: Training Loss=0.25391
# Step 900/3755: Training Loss=0.24307
# Epoch 3 | Training Loss: 0.0008  Accuracy: valset=0.8748
# Saving Best Model at epoch 3
# Step 950/3755: Training Loss=0.04356
# Step 1000/3755: Training Loss=0.18783
# Step 1050/3755: Training Loss=0.17731
# Step 1100/3755: Training Loss=0.17065
# Step 1150/3755: Training Loss=0.15173
# Step 1200/3755: Training Loss=0.17185
# Step 1250/3755: Training Loss=0.17469
# Epoch 4 | Training Loss: 0.0006  Accuracy: valset=0.8956
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.11960
# Step 1350/3755: Training Loss=0.10862
# Step 1400/3755: Training Loss=0.12663
# Step 1450/3755: Training Loss=0.12226
# Step 1500/3755: Training Loss=0.13881
# Step 1550/3755: Training Loss=0.11635
# Epoch 5 | Training Loss: 0.0004  Accuracy: valset=0.8996
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.05264
# Step 1650/3755: Training Loss=0.06939
# Step 1700/3755: Training Loss=0.07336
# Step 1750/3755: Training Loss=0.07376
# Step 1800/3755: Training Loss=0.09163
# Step 1850/3755: Training Loss=0.09185
# Epoch 6 | Training Loss: 0.0003  Accuracy: valset=0.9008
# Saving Best Model at epoch 6
# Step 1900/3755: Training Loss=0.02744
# Step 1950/3755: Training Loss=0.06454
# Step 2000/3755: Training Loss=0.05854
# Step 2050/3755: Training Loss=0.06431
# Step 2100/3755: Training Loss=0.06115
# Step 2150/3755: Training Loss=0.07227
# Epoch 7 | Training Loss: 0.0002  Accuracy: valset=0.8976
# Step 2200/3755: Training Loss=0.00848
# Step 2250/3755: Training Loss=0.03894
# Step 2300/3755: Training Loss=0.04693
# Step 2350/3755: Training Loss=0.04740
# Step 2400/3755: Training Loss=0.04326
# Step 2450/3755: Training Loss=0.05051
# Step 2500/3755: Training Loss=0.06530
# Epoch 8 | Training Loss: 0.0002  Accuracy: valset=0.9010
# Saving Best Model at epoch 8
# Step 2550/3755: Training Loss=0.02562
# Step 2600/3755: Training Loss=0.03757
# Step 2650/3755: Training Loss=0.03375
# Step 2700/3755: Training Loss=0.02801
# Step 2750/3755: Training Loss=0.03246
# Step 2800/3755: Training Loss=0.04307
# Epoch 9 | Training Loss: 0.0001  Accuracy: valset=0.8964
# Step 2850/3755: Training Loss=0.02398
# Step 2900/3755: Training Loss=0.02065
# Step 2950/3755: Training Loss=0.02845
# Step 3000/3755: Training Loss=0.02302
# Step 3050/3755: Training Loss=0.03281
# Step 3100/3755: Training Loss=0.02968
# Epoch 10 | Training Loss: 0.0001  Accuracy: valset=0.8932
# Step 3150/3755: Training Loss=0.01598
# Step 3200/3755: Training Loss=0.02476
# Step 3250/3755: Training Loss=0.01835
# Step 3300/3755: Training Loss=0.02478
# Step 3350/3755: Training Loss=0.02453
# Step 3400/3755: Training Loss=0.03340
# Epoch 11 | Training Loss: 0.0001  Accuracy: valset=0.8998
# Step 3450/3755: Training Loss=0.00075
# Step 3500/3755: Training Loss=0.02326
# Step 3550/3755: Training Loss=0.02066
# Step 3600/3755: Training Loss=0.01869
# Step 3650/3755: Training Loss=0.01871
# Step 3700/3755: Training Loss=0.01754
# Step 3750/3755: Training Loss=0.02032
# Epoch 12 | Training Loss: 0.0001  Accuracy: valset=0.8924
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     10000
#          1.0       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000
#
# Accuracy:  0.99865
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90      2500
#          1.0       0.89      0.91      0.90      2500
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
# Accuracy:  0.901
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.89      0.89     12500
#          1.0       0.89      0.90      0.89     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.89084

# %% [markdown]
# ### Variant 2 [Embedding]
# For this one, we will compare the effect of different embedding methodologies

# %%
hidden_size=256
model_type="gru"

# %% [markdown]
# #### Vanilla Embedding

# %%
args = RNN_ARG(lr, vocab_size, embedding_size=hidden_size, hidden_size=hidden_size,
            output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
            rnn_base_cell=model_type, embedding_type="vanilla", embedding_learnable=True, bidirectional=True)

trainer = Trainer(exp_name=f"{model_type}_rnn_vanilla_embedding", seed=seed, device=device, args=args, info_steps=100)
trainer.train(num_epochs, bs, num_workers, trainset, testset, valset)

# This one is obtained above

# %% [markdown]
# #### GLoVE Embedding [Fixed]

# %%
args = RNN_ARG(lr, vocab_size, embedding_size=hidden_size, hidden_size=hidden_size,
            output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
            rnn_base_cell=model_type, embedding_type="glove", embedding_learnable=False, bidirectional=True)

trainer = Trainer(exp_name=f"{model_type}_rnn_glove_fixed_embedding", seed=seed, device=device, args=args, info_steps=100)
trainer.train(num_epochs, bs, num_workers, trainset, testset, valset)
# Out:
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_glove_fixed_embedding
# ------------------------------------------------------------
# Initialize by GLoVE word embedding
# Fix the Embedding Layer
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.66063
# Step 200/3755: Training Loss=0.65737
# Step 300/3755: Training Loss=0.64342
# Epoch 1 | Training Loss: 0.0021  Accuracy: valset=0.6720
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.46445
# Step 500/3755: Training Loss=0.47657
# Step 600/3755: Training Loss=0.43359
# Epoch 2 | Training Loss: 0.0015  Accuracy: valset=0.8200
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.29086
# Step 800/3755: Training Loss=0.36216
# Step 900/3755: Training Loss=0.34737
# Epoch 3 | Training Loss: 0.0011  Accuracy: valset=0.8504
# Saving Best Model at epoch 3
# Step 1000/3755: Training Loss=0.16759
# Step 1100/3755: Training Loss=0.28038
# Step 1200/3755: Training Loss=0.27922
# Epoch 4 | Training Loss: 0.0009  Accuracy: valset=0.8418
# Step 1300/3755: Training Loss=0.10920
# Step 1400/3755: Training Loss=0.21752
# Step 1500/3755: Training Loss=0.22651
# Epoch 5 | Training Loss: 0.0007  Accuracy: valset=0.8794
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.06055
# Step 1700/3755: Training Loss=0.19385
# Step 1800/3755: Training Loss=0.17731
# Epoch 6 | Training Loss: 0.0006  Accuracy: valset=0.8740
# Step 1900/3755: Training Loss=0.03105
# Step 2000/3755: Training Loss=0.13864
# Step 2100/3755: Training Loss=0.15908
# Epoch 7 | Training Loss: 0.0005  Accuracy: valset=0.8786
# Step 2200/3755: Training Loss=0.00992
# Step 2300/3755: Training Loss=0.11079
# Step 2400/3755: Training Loss=0.12614
# Step 2500/3755: Training Loss=0.12691
# Epoch 8 | Training Loss: 0.0004  Accuracy: valset=0.8676
# Step 2600/3755: Training Loss=0.07935
# Step 2700/3755: Training Loss=0.10112
# Step 2800/3755: Training Loss=0.10035
# Epoch 9 | Training Loss: 0.0003  Accuracy: valset=0.8766
# Step 2900/3755: Training Loss=0.06447
# Step 3000/3755: Training Loss=0.08892
# Step 3100/3755: Training Loss=0.10160
# Epoch 10 | Training Loss: 0.0003  Accuracy: valset=0.8794
# Step 3200/3755: Training Loss=0.05263
# Step 3300/3755: Training Loss=0.06843
# Step 3400/3755: Training Loss=0.08959
# Epoch 11 | Training Loss: 0.0003  Accuracy: valset=0.8650
# Step 3500/3755: Training Loss=0.04165
# Step 3600/3755: Training Loss=0.05968
# Step 3700/3755: Training Loss=0.06826
# Epoch 12 | Training Loss: 0.0002  Accuracy: valset=0.8614
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96     10000
#          1.0       0.96      0.96      0.96     10000
#
#     accuracy                           0.96     20000
#    macro avg       0.96      0.96      0.96     20000
# weighted avg       0.96      0.96      0.96     20000
#
# Accuracy:  0.95975
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.86      0.88      2500
#          1.0       0.87      0.90      0.88      2500
#
#     accuracy                           0.88      5000
#    macro avg       0.88      0.88      0.88      5000
# weighted avg       0.88      0.88      0.88      5000
#
# Accuracy:  0.8794
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.87      0.88     12500
#          1.0       0.88      0.89      0.88     12500
#
#     accuracy                           0.88     25000
#    macro avg       0.88      0.88      0.88     25000
# weighted avg       0.88      0.88      0.88     25000
#
# Accuracy:  0.88268

# %% [markdown]
# #### GLoVE Embedding [Learnable]

# %%
args = RNN_ARG(lr, vocab_size, embedding_size=hidden_size, hidden_size=hidden_size,
            output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
            rnn_base_cell=model_type, embedding_type="glove", embedding_learnable=True, bidirectional=True)

trainer = Trainer(exp_name=f"{model_type}_rnn_glove_learnable_embedding", seed=seed, device=device, args=args, info_steps=100)
trainer.train(num_epochs, bs, num_workers, trainset, testset, valset)
# Out:
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_glove_learnable_embedding
# ------------------------------------------------------------
# Initialize by GLoVE word embedding
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 100/3755: Training Loss=0.65632
# Step 200/3755: Training Loss=0.57252
# Step 300/3755: Training Loss=0.44468
# Epoch 1 | Training Loss: 0.0018  Accuracy: valset=0.7982
# Saving Best Model at epoch 1
# Step 400/3755: Training Loss=0.31842
# Step 500/3755: Training Loss=0.31146
# Step 600/3755: Training Loss=0.29407
# Epoch 2 | Training Loss: 0.0010  Accuracy: valset=0.8856
# Saving Best Model at epoch 2
# Step 700/3755: Training Loss=0.15936
# Step 800/3755: Training Loss=0.20107
# Step 900/3755: Training Loss=0.22090
# Epoch 3 | Training Loss: 0.0007  Accuracy: valset=0.8720
# Step 1000/3755: Training Loss=0.08850
# Step 1100/3755: Training Loss=0.13501
# Step 1200/3755: Training Loss=0.14639
# Epoch 4 | Training Loss: 0.0005  Accuracy: valset=0.9002
# Saving Best Model at epoch 4
# Step 1300/3755: Training Loss=0.04073
# Step 1400/3755: Training Loss=0.09176
# Step 1500/3755: Training Loss=0.10399
# Epoch 5 | Training Loss: 0.0003  Accuracy: valset=0.9010
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.01815
# Step 1700/3755: Training Loss=0.06157
# Step 1800/3755: Training Loss=0.05805
# Epoch 6 | Training Loss: 0.0002  Accuracy: valset=0.8908
# Step 1900/3755: Training Loss=0.00895
# Step 2000/3755: Training Loss=0.04066
# Step 2100/3755: Training Loss=0.05446
# Epoch 7 | Training Loss: 0.0002  Accuracy: valset=0.9026
# Saving Best Model at epoch 7
# Step 2200/3755: Training Loss=0.00216
# Step 2300/3755: Training Loss=0.02760
# Step 2400/3755: Training Loss=0.03426
# Step 2500/3755: Training Loss=0.03950
# Epoch 8 | Training Loss: 0.0001  Accuracy: valset=0.8952
# Step 2600/3755: Training Loss=0.02512
# Step 2700/3755: Training Loss=0.03231
# Step 2800/3755: Training Loss=0.02791
# Epoch 9 | Training Loss: 0.0001  Accuracy: valset=0.9028
# Saving Best Model at epoch 9
# Step 2900/3755: Training Loss=0.02083
# Step 3000/3755: Training Loss=0.02813
# Step 3100/3755: Training Loss=0.02613
# Epoch 10 | Training Loss: 0.0001  Accuracy: valset=0.9012
# Step 3200/3755: Training Loss=0.01181
# Step 3300/3755: Training Loss=0.02011
# Step 3400/3755: Training Loss=0.02462
# Epoch 11 | Training Loss: 0.0001  Accuracy: valset=0.9028
# Step 3500/3755: Training Loss=0.00892
# Step 3600/3755: Training Loss=0.02266
# Step 3700/3755: Training Loss=0.02799
# Epoch 12 | Training Loss: 0.0001  Accuracy: valset=0.9010
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     10000
#          1.0       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     20000
#    macro avg       1.00      1.00      1.00     20000
# weighted avg       1.00      1.00      1.00     20000
#
# Accuracy:  0.99905
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.87      0.90      2500
#          1.0       0.88      0.94      0.91      2500
#
#     accuracy                           0.90      5000
#    macro avg       0.90      0.90      0.90      5000
# weighted avg       0.90      0.90      0.90      5000
#
# Accuracy:  0.9028
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89     12500
#          1.0       0.87      0.93      0.90     12500
#
#     accuracy                           0.89     25000
#    macro avg       0.89      0.89      0.89     25000
# weighted avg       0.89      0.89      0.89     25000
#
# Accuracy:  0.89172

# %% [markdown]
# #### BERT Representation as Embedding

# %%
from transformers import BertTokenizer
tokenizer_bert = BertTokenizer.from_pretrained("bert-base-uncased")

# Need to reconstruct Dataset since changing the tokenizer
trainset_bert = IMDB50(train_text, train_label, tokenizer_bert)
valset_bert = IMDB50(validation_text, validation_label, tokenizer_bert)
testset_bert = IMDB50(test_text, test_label, tokenizer_bert)

bert_d_model = 768
args = RNN_ARG(lr, vocab_size, embedding_size=bert_d_model, hidden_size=hidden_size,
            output_size=output_size, num_layers=num_layers, embedding_dropout=embedding_dropout, output_dropout=output_dropout,
            rnn_base_cell=model_type, embedding_type="bert", embedding_learnable=False, bidirectional=True)

trainer = Trainer(exp_name=f"{model_type}_rnn_bert_representation", seed=seed, device=device, args=args, info_steps=50)
trainer.train(num_epochs, bs, num_workers, trainset_bert, testset_bert, valset_bert)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ------------------------------------------------------------
# Running Experiment:  gru_rnn_bert_representation
# ------------------------------------------------------------
# Use BERT representation [fixed]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BERT layers are freezed
# Total Training Steps Per Epoch: 313
# Training Progress:   0%|          | 0/3755 [00:00<?, ?it/s]
# Step 50/3755: Training Loss=0.62250
# Step 100/3755: Training Loss=0.54019
# Step 150/3755: Training Loss=0.44202
# Step 200/3755: Training Loss=0.36428
# Step 250/3755: Training Loss=0.35120
# Step 300/3755: Training Loss=0.31501
# Epoch 1 | Training Loss: 0.0014  Accuracy: valset=0.8910
# Saving Best Model at epoch 1
# Step 350/3755: Training Loss=0.21602
# Step 400/3755: Training Loss=0.28300
# Step 450/3755: Training Loss=0.28258
# Step 500/3755: Training Loss=0.29496
# Step 550/3755: Training Loss=0.29528
# Step 600/3755: Training Loss=0.28529
# Epoch 2 | Training Loss: 0.0009  Accuracy: valset=0.9078
# Saving Best Model at epoch 2
# Step 650/3755: Training Loss=0.12490
# Step 700/3755: Training Loss=0.28069
# Step 750/3755: Training Loss=0.24333
# Step 800/3755: Training Loss=0.25858
# Step 850/3755: Training Loss=0.26847
# Step 900/3755: Training Loss=0.25094
# Epoch 3 | Training Loss: 0.0008  Accuracy: valset=0.9078
# Step 950/3755: Training Loss=0.04752
# Step 1000/3755: Training Loss=0.22230
# Step 1050/3755: Training Loss=0.22993
# Step 1100/3755: Training Loss=0.23382
# Step 1150/3755: Training Loss=0.21920
# Step 1200/3755: Training Loss=0.23556
# Step 1250/3755: Training Loss=0.24815
# Epoch 4 | Training Loss: 0.0007  Accuracy: valset=0.9072
# Step 1300/3755: Training Loss=0.20991
# Step 1350/3755: Training Loss=0.21780
# Step 1400/3755: Training Loss=0.20572
# Step 1450/3755: Training Loss=0.20992
# Step 1500/3755: Training Loss=0.21128
# Step 1550/3755: Training Loss=0.21161
# Epoch 5 | Training Loss: 0.0007  Accuracy: valset=0.9178
# Saving Best Model at epoch 5
# Step 1600/3755: Training Loss=0.13202
# Step 1650/3755: Training Loss=0.18483
# Step 1700/3755: Training Loss=0.18463
# Step 1750/3755: Training Loss=0.20575
# Step 1800/3755: Training Loss=0.19785
# Step 1850/3755: Training Loss=0.20176
# Epoch 6 | Training Loss: 0.0006  Accuracy: valset=0.9164
# Step 1900/3755: Training Loss=0.06688
# Step 1950/3755: Training Loss=0.16373
# Step 2000/3755: Training Loss=0.16723
# Step 2050/3755: Training Loss=0.17341
# Step 2100/3755: Training Loss=0.18169
# Step 2150/3755: Training Loss=0.18225
# Epoch 7 | Training Loss: 0.0005  Accuracy: valset=0.9112
# Step 2200/3755: Training Loss=0.03101
# Step 2250/3755: Training Loss=0.14159
# Step 2300/3755: Training Loss=0.13831
# Step 2350/3755: Training Loss=0.13344
# Step 2400/3755: Training Loss=0.14993
# Step 2450/3755: Training Loss=0.17397
# Step 2500/3755: Training Loss=0.15327
# Epoch 8 | Training Loss: 0.0005  Accuracy: valset=0.9176
# Step 2550/3755: Training Loss=0.11878
# Step 2600/3755: Training Loss=0.12333
# Step 2650/3755: Training Loss=0.13535
# Step 2700/3755: Training Loss=0.14783
# Step 2750/3755: Training Loss=0.13496
# Step 2800/3755: Training Loss=0.11217
# Epoch 9 | Training Loss: 0.0004  Accuracy: valset=0.9056
# Step 2850/3755: Training Loss=0.07875
# Step 2900/3755: Training Loss=0.11034
# Step 2950/3755: Training Loss=0.12579
# Step 3000/3755: Training Loss=0.11146
# Step 3050/3755: Training Loss=0.10911
# Step 3100/3755: Training Loss=0.11337
# Epoch 10 | Training Loss: 0.0004  Accuracy: valset=0.9126
# Step 3150/3755: Training Loss=0.04234
# Step 3200/3755: Training Loss=0.10395
# Step 3250/3755: Training Loss=0.10346
# Step 3300/3755: Training Loss=0.10734
# Step 3350/3755: Training Loss=0.11870
# Step 3400/3755: Training Loss=0.09732
# Epoch 11 | Training Loss: 0.0003  Accuracy: valset=0.9144
# Step 3450/3755: Training Loss=0.00634
# Step 3500/3755: Training Loss=0.10589
# Step 3550/3755: Training Loss=0.07774
# Step 3600/3755: Training Loss=0.09606
# Step 3650/3755: Training Loss=0.08910
# Step 3700/3755: Training Loss=0.10854
# Step 3750/3755: Training Loss=0.07751
# Epoch 12 | Training Loss: 0.0003  Accuracy: valset=0.9152
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.95     10000
#          1.0       0.96      0.95      0.95     10000
#
#     accuracy                           0.95     20000
#    macro avg       0.95      0.95      0.95     20000
# weighted avg       0.95      0.95      0.95     20000
#
# Accuracy:  0.9533
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.92      0.92      2500
#          1.0       0.92      0.91      0.92      2500
#
#     accuracy                           0.92      5000
#    macro avg       0.92      0.92      0.92      5000
# weighted avg       0.92      0.92      0.92      5000
#
# Accuracy:  0.9178
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.92     12500
#          1.0       0.93      0.92      0.92     12500
#
#     accuracy                           0.92     25000
#    macro avg       0.92      0.92      0.92     25000
# weighted avg       0.92      0.92      0.92     25000
#
# Accuracy:  0.92088

# %%
# Saving bert variant excluding bert part as it's too large

state_dict = trainer.model.state_dict()
state_dict_copy = state_dict.copy()

layer_keys_to_remove = [key for key in state_dict_copy if 'embedding_layer' in key]

for key in layer_keys_to_remove:
    del state_dict_copy[key]

torch.save(state_dict_copy, 'gru_rnn_bert_representation_best.pt')

# %%
state_dict = torch.load('gru_rnn_bert_representation_best.pt')
trainer.model.load_state_dict(state_dict, strict=False)
